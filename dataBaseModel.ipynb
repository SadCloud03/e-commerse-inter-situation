# %% [markdown]
# ### This file would be for the procces of modeling the data base

# %% [markdown]
# ![image.png](attachment:image.png)
#
# with all the information that i took from seeing the .csvs i came with this

# %%
# import the module pandas 
import pandas as pd

# %% [markdown]
# ## Tables of the dataBase

# %% [markdown]
# ![image.png](attachment:image.png)
#
# since this is the datasets that we have ill be looking into every one of them, but its clear that the tables of the relational data base would be:
# * categories
# * countries
# * currency_rates_template
# * order_items
# * orders
# * product_details
# * products
# * shipping_regions
# * users

# %% [markdown]
# ## Categories
# taking a deeper look into *categories.csv*

# %%
# creating a Data frame:
categories_df = pd.read_csv('dataset/categories.csv')

# categories_df initial info
categories_df.info()

# display all categories_df
display(categories_df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      24 non-null     int64
#  1   slug    24 non-null     str
#  2   name    24 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 708.0 bytes
#     id                 slug                 name
# 0    1               beauty               Beauty
# 1    2           fragrances           Fragrances
# 2    3            furniture            Furniture
# 3    4            groceries            Groceries
# 4    5      home-decoration      Home Decoration
# 5    6  kitchen-accessories  Kitchen Accessories
# 6    7              laptops              Laptops
# 7    8          mens-shirts          Mens Shirts
# 8    9           mens-shoes           Mens Shoes
# 9   10         mens-watches         Mens Watches
# 10  11   mobile-accessories   Mobile Accessories
# 11  12           motorcycle           Motorcycle
# ...

# %% [markdown]
# ## Countries
# Deeper look into *countries.csv*

# %%
# creating the Data Frame
countries_df = pd.read_csv('dataset/countries.csv')

# initial info of countries_df
countries_df.info()

# display of countries_df
display(countries_df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        24 non-null     str
#  1   name        24 non-null     str
#  2   region      24 non-null     str
#  3   population  24 non-null     int64
# dtypes: int64(1), str(3)
# memory usage: 900.0 bytes
#    code            name    region  population
# 0    AR       Argentina  Americas    46735004
# 1    AU       Australia   Oceania    27536874
# 2    BO         Bolivia  Americas    11365333
# 3    BR          Brazil  Americas   213421037
# 4    CA          Canada  Americas    41651653
# 5    CL           Chile  Americas    20206953
# 6    CO        Colombia  Americas    53057212
# 7    DE         Germany    Europe    83491249
# 8    ES           Spain    Europe    49315949
# 9    FR          France    Europe    66351959
# 10   GB  United Kingdom    Europe    69281437
# ...

# %% [markdown]
# ## Order_items
# Deeper look into *order_items.csv*

# %%
# creating the data Frame
order_items_df = pd.read_csv('dataset/order_items.csv')

# initial info 
order_items_df.info()

# this time only show arround 20
order_items_df.head(20)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45965 entries, 0 to 45964
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          45965 non-null  int64
#  1   order_id    45965 non-null  int64
#  2   product_id  45965 non-null  int64
#  3   quantity    45965 non-null  int64
#  4   unit_price  45965 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 1.8 MB
#     id  order_id  product_id  quantity  unit_price
# 0    1         1           1         4       11.54
# 1    2         2         115         1    17981.48
# 2    3         2         180         2       55.16
# 3    4         3          34         1        9.48
# 4    5         3         155         2       24.00
# 5    6         4          53         4       12.91
# 6    7         4         131         1      301.24
# 7    8         5         187         1       58.07
# 8    9         6          91         3      115.21
# ...

# %% [markdown]
# ## Orders
# Deeper look into *orders.csv*

# %%
# creating the data Frame
orders_df = pd.read_csv('dataset/orders.csv')

# initial info of orders_df
orders_df.info()

# this time show arround 20 again 
orders_df.head(20)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            22000 non-null  int64
#  1   user_id       22000 non-null  int64
#  2   order_date    22000 non-null  str
#  3   total_amount  22000 non-null  float64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 687.6 KB
#     id  user_id  order_date  total_amount
# 0    1     2485  2024-10-23         46.16
# 1    2     2047  2024-12-14      18091.80
# 2    3     2334  2025-10-29         57.48
# 3    4     1982  2024-11-02        352.88
# 4    5      680  2024-08-16         58.07
# 5    6     3316  2025-04-29       3127.11
# 6    7     1967  2024-08-21         10.05
# 7    8      891  2025-06-16        304.80
# 8    9     1205  2025-11-29       4280.40
# 9   10     2222  2024-08-09         92.21
# 10  11     2003  2025-12-16         41.18
# 11  12     2949  2024-06-17         21.98
# ...

# %% [markdown]
# ## ProductsDetails
# Deeper look into *product_details.csv*

# %%
# creating the data frame
product_details_df = pd.read_csv('dataset/product_details.csv')

# initial info of product_details_df
product_details_df.info()

# display 20 lines of product_details_df
product_details_df.head(20)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  194 non-null    int64
#  1   stock       194 non-null    int64
#  2   rating      194 non-null    float64
#  3   weight      194 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 6.2 KB
#     product_id  stock  rating  weight
# 0            1     99    2.56     4.0
# 1            2     34    2.86     9.0
# 2            3     89    4.64     8.0
# 3            4     91    4.36     1.0
# 4            5     79    4.32     8.0
# 5            6     29    4.37     7.0
# 6            7     58    4.26     7.0
# 7            8     98    3.80     4.0
# 8            9      4    3.96     6.0
# 9           10     91    2.74     7.0
# 10          11     88    4.77    10.0
# 11          12     60    3.92     6.0
# 12          13     64    2.87     2.0
# ...

# %% [markdown]
# ## Products
# Deeper look into *products.csv*

# %%
# creating the data Frame
products_df = pd.read_csv('dataset/products.csv')

# initial info product_df
products_df.info()

# show only 20 rows of products_df
products_df.head(20)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           194 non-null    int64
#  1   name         194 non-null    str
#  2   price        194 non-null    float64
#  3   category_id  194 non-null    int64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 6.2 KB
#     id                                       name    price  category_id
# 0    1              Essence Mascara Lash Princess    11.00            1
# 1    2              Eyeshadow Palette with Mirror    19.30            1
# 2    3                            Powder Canister    15.30            1
# 3    4                               Red Lipstick    13.11            1
# 4    5                            Red Nail Polish    10.09            1
# 5    6                        Calvin Klein CK One    55.43            2
# ...

# %% [markdown]
# ## ShippingRegions
# Deeper look into *shipping_regions.csv*

# %%
# create the data Frame
shipping_regions_df = pd.read_csv('dataset/shipping_regions.csv')

# initial info of shipping_regions_df
shipping_regions_df.info()

# show shipping_regions_df
display(shipping_regions_df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country_code    24 non-null     str
#  1   region          0 non-null      float64
#  2   shipping_zone   0 non-null      float64
#  3   estimated_days  0 non-null      float64
# dtypes: float64(3), str(1)
# memory usage: 900.0 bytes
#    country_code  region  shipping_zone  estimated_days
# 0            AR     NaN            NaN             NaN
# 1            AU     NaN            NaN             NaN
# 2            BO     NaN            NaN             NaN
# 3            BR     NaN            NaN             NaN
# 4            CA     NaN            NaN             NaN
# 5            CL     NaN            NaN             NaN
# 6            CO     NaN            NaN             NaN
# 7            DE     NaN            NaN             NaN
# 8            ES     NaN            NaN             NaN
# ...

# %% [markdown]
# ## Users
# Deeper look into *users.csv*

# %%
# create de data Frame
users_df = pd.read_csv('dataset/users.csv')

# initial info of user_df
users_df.info()

# show only 20 rows of users_df
users_df.head(20)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            3500 non-null   int64
#  1   name          3500 non-null   str
#  2   email         3500 non-null   str
#  3   country_code  3500 non-null   str
#  4   created_at    3500 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 136.8 KB
#     id               name                          email country_code  \
# 0    1        Leo Pereira        leo.pereira@hotmail.com           AU
# 1    2        Sofia Perez          sofia.perez@gmail.com           BR
# 2    3     Amelia Sanchez     amelia.sanchez@hotmail.com           PY
# 3    4          Noah Diaz          noah.diaz@outlook.com           AR
# 4    5     Catalina Brown      catalina.brown@zolver.com           ES
# 5    6       Mateo Romero       mateo.romero@outlook.com           BR
# ...

# %% [markdown]
# ## the final schema is now in the foulder /data_base
